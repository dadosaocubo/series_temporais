# %% [markdown]
# <img src="https://raw.githubusercontent.com/dadosaocubo/classificacao/master/DadosAoCubo.png" alt="drawing" width="300"/>

# %% [markdown]
# # Ciência de Dados para Mercado de Ações

# %% [markdown]
# [__D3__](https://dadosaocubo.com/) by [__Tiago Dias__](https://www.linkedin.com/in/diasctiago/)
# <br/><br/>
# Objetivo: Enteder como é possível aplicar Ciência de Dados para Mercado de Ações
# <br/><br/>
# Tópicos da aula:
# *   Oceans14
# *   Yahoo Finance
# *   Série Temporal
# *   Modelo

# %% [markdown]
# ## Mercado de Ações ao Cubo

# %% [markdown]
# ### Oceans14

# %%
from requests import request
from json import loads
from pandas import read_html

# %% [markdown]
# Opções de consultas de ações:
#
# *   **Empresa**: vale ----------> **Ação**:vale3
# *   **Empresa**: petrobras ----> **Ação**:petr
# *   **Empresa**: oi -------------> **Ação**:oibr
# *   **Empresa**: braskem -----> **Ação**:brkm
# *   **Empresa**: americanas --> **Ação**:amer3
#
# Para mais opções consulte: [Oceans14](https://www.oceans14.com.br/acoes/)

# %%
empresa   = 'petrobras'
acao      = 'petr'
url       = f'https://www.oceans14.com.br/acoes/{empresa}/{acao}/balanco-dividendos'
resposta  = request('GET', url, headers={'User-Agent': 'Dados ao Cubo'})

# %%
resposta
# Out:
# <Response [200]>

# %%
dados = read_html(resposta.text)

# %%
len(dados)
# Out:
# 15

# %%
dados[0]
# Out:
#         0         1       2
# 0   CXSE3   R$ 8,24   0,61%
# 1   VALE3  R$ 93,97   0,25%
# 2   BBSE3  R$ 34,36   0,20%
# 3   WEGE3  R$ 38,50  -0,03%
# 4  TAEE11  R$ 34,91  -0,06%
# 5   BBAS3  R$ 35,47  -0,28%
# 6  SAPR11  R$ 17,11  -0,87%
# 7   ITUB4  R$ 25,67  -1,19%
# 8   ITSA4   R$ 8,59  -1,26%
# 9   B3SA3  R$ 13,12  -1,87%

# %%
dados[3]
# Out:
#                                       Cotação PETR4
# 0  -0,97% R$ 24,39 13/01/2023 12:21 Var. 12m: 0,99%

# %%
dados[4]
# Out:
#                                       Cotação PETR3
# 0  -0,50% R$ 27,61 13/01/2023 12:21 Var. 12m: 0,51%

# %%
dados[5]
# Out:
# Empty DataFrame
# Columns: [Tipo, Data Aprovação, Data Com, Data Pgto, Valor, Descrição]
# Index: []

# %%
dados[6]
# Out:
# Empty DataFrame
# Columns: [Tipo, Data Aprovação, Data Com, Data Pgto, Valor, Descrição]
# Index: []

# %%
dados[7]
# Out:
#                    0  1
# 0                NaN  .
# 1    Receita líquida  .
# 2             Custos  .
# 3    Resultado bruto  .
# 4       Margem bruta  .
# 5     Despesas oper.  .
# 6   Res. operacional  .
# 7       Margem Oper.  .
# 8    Res. Financeiro  .
# 9          IR e CSSL  .
# 10    Op. descontin.  .
# 11     Lucro líquido  .
# 12    Margem líquida  .

# %% [markdown]
# ### Yahoo Finance

# %%
# !pip install yahooquery==2.2.15
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 KB 821.9 kB/s eta 0:00:00
# ...

# %%
from yahooquery import Ticker
import pandas as pd

# %%
symbols = ['aapl', 'amzn', 'nflx', 'goog', 'meta']

faang = Ticker(symbols)

# %%
pd.DataFrame(faang.summary_profile)
# Out:
#                                                                   aapl  \
# address1                                            One Apple Park Way
# city                                                         Cupertino
# state                                                               CA
# zip                                                              95014
# country                                                  United States
# phone                                                     408 996 1010
# website                                          https://www.apple.com
# industry                                          Consumer Electronics
# sector                                                      Technology
# longBusinessSummary  Apple Inc. designs, manufactures, and markets ...
# fullTimeEmployees                                               164000
# companyOfficers                                                     []
# ...

# %%
pd.DataFrame(faang.summary_detail)
# Out:
#                                              aapl           amzn  \
# maxAge                                          1              1
# priceHint                                       2              2
# previousClose                              141.86          97.18
# open                                       143.17         98.235
# dayLow                                      141.9          96.92
# dayHigh                                    144.25          99.49
# regularMarketPreviousClose                 141.86          97.18
# regularMarketOpen                          143.17         98.235
# regularMarketDayLow                         141.9          96.92
# regularMarketDayHigh                       144.25          99.49
# dividendRate                                 0.92            NaN
# dividendYield                              0.0065            NaN
# exDividendDate                2022-11-04 00:00:00            NaN
# ...

# %%
symbol = Ticker('PETR4.SA')

# %%
pd.DataFrame(symbol.summary_detail)
# Out:
#                                          PETR4.SA
# algorithm                                    None
# ask                                         26.07
# askSize                                         0
# averageDailyVolume10Day                  68667460
# averageVolume                            93510059
# averageVolume10days                      68667460
# beta                                     1.008477
# bid                                         26.06
# bidSize                                         0
# coinMarketCapLink                            None
# currency                                      BRL
# dayHigh                                      27.2
# dayLow                                       25.8
# dividendRate                                20.02
# dividendYield                              0.7525
# exDividendDate                2022-11-22 00:00:00
# fiftyDayAverage                           24.5776
# fiftyTwoWeekHigh                            38.39
# ...

# %%
symbol.income_statement()
# Out:
#            asOfDate periodType currencyCode  BasicAverageShares  BasicEPS  \
# symbol
# PETR4.SA 2019-12-31        12M          USD        1.304450e+10      0.78
# PETR4.SA 2020-03-31        TTM          USD                 NaN       NaN
# PETR4.SA 2020-12-31        12M          USD        1.304420e+10      0.09
# PETR4.SA 2021-12-31        12M          USD        1.304420e+10      1.52
# PETR4.SA 2022-09-30        TTM          USD                 NaN       NaN
#
#           CostOfRevenue  DepreciationAmortizationDepletionIncomeStatement  \
# symbol
# PETR4.SA   4.573200e+10                                       158000000.0
# PETR4.SA            NaN                                               NaN
# PETR4.SA   2.919500e+10                                       653000000.0
# PETR4.SA   4.316400e+10                                        86000000.0
# PETR4.SA   5.734600e+10                                       257000000.0
#
# ...

# %%
symbol.balance_sheet()
# Out:
#            asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# PETR4.SA 2019-12-31        12M          USD     5.601000e+09
# PETR4.SA 2020-12-31        12M          USD     6.859000e+09
# PETR4.SA 2021-12-31        12M          USD     5.483000e+09
#
#           AccountsReceivable  AccumulatedDepreciation  \
# symbol
# PETR4.SA        3.762000e+09            -8.662300e+10
# PETR4.SA        4.731000e+09            -1.006740e+11
# PETR4.SA        6.368000e+09            -9.107700e+10
#
#           AssetsHeldForSaleCurrent  AvailableForSaleSecurities  \
# symbol
# PETR4.SA              2.564000e+09                  58000000.0
# PETR4.SA              7.850000e+08                  44000000.0
# PETR4.SA              2.490000e+09                  44000000.0
#
#           CapitalLeaseObligations  CapitalStock  ...  TotalCapitalization  \
# symbol                                           ...
# PETR4.SA             2.386100e+10  1.071010e+11  ...         1.321140e+11
# ...

# %%
symbol.history(period='max')
# Out:
#                           high      close       open        low        volume  \
# symbol   date
# PETR4.SA 2000-01-03   5.875000   5.875000   5.875000   5.875000  3.538944e+10
#          2000-01-04   5.550000   5.550000   5.550000   5.550000  2.886144e+10
#          2000-01-05   5.494000   5.494000   5.494000   5.494000  4.303360e+10
#          2000-01-06   5.475000   5.475000   5.475000   5.475000  3.405568e+10
#          2000-01-07   5.500000   5.500000   5.500000   5.500000  2.091264e+10
# ...                        ...        ...        ...        ...           ...
#          2023-01-20  26.600000  26.370001  25.889999  25.420000  1.142195e+08
#          2023-01-23  27.600000  26.790001  26.270000  26.129999  8.767810e+07
#          2023-01-24  27.530001  26.600000  27.469999  26.370001  6.579400e+07
#          2023-01-25  27.080000  26.940001  26.549999  26.010000  5.183290e+07
#          2023-01-26  27.200001  26.049999  27.090000  25.799999  4.896520e+07
#
# ...

# %%
symbol.history(start="2023-01-01", end="2023-01-10")
# Out:
#                         volume       high        low      close       open  \
# symbol   date
# PETR4.SA 2023-01-02   78424700  23.809999  22.799999  22.920000  23.540001
#          2023-01-03   96750300  23.100000  22.129999  22.340000  22.940001
#          2023-01-04  129504000  23.590000  21.830000  23.049999  21.959999
#          2023-01-05   73886000  24.040001  23.150000  23.879999  23.340000
#          2023-01-06   51851500  24.320000  23.549999  23.740000  23.940001
#          2023-01-09   46385200  24.000000  23.250000  23.870001  23.500000
#
#                       adjclose
# symbol   date
# PETR4.SA 2023-01-02  22.920000
#          2023-01-03  22.340000
#          2023-01-04  23.049999
#          2023-01-05  23.879999
#          2023-01-06  23.740000
#          2023-01-09  23.870001

# %%
#data = symbol.history(period='max').reset_index()[['date','close']]
data = symbol.history(start="2022-10-01", end="2023-01-26").reset_index()[['date','close']]
data.head()
# Out:
#          date      close
# 0  2022-10-03  32.180000
# 1  2022-10-04  31.370001
# 2  2022-10-05  32.549999
# 3  2022-10-06  33.660000
# 4  2022-10-07  33.630001

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    59 non-null     object
#  1   close   59 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.0+ KB

# %%
data = data.set_index(pd.to_datetime(data['date']))

# %%
serie = data['close']

# %%
serie.head(3)
# Out:
# date
# 2022-11-01    29.860001
# 2022-11-03    29.950001
# 2022-11-04    28.299999
# Name: close, dtype: float64

# %%
serie.tail(3)
# Out:
# date
# 2023-01-23    26.790001
# 2023-01-24    26.600000
# 2023-01-25    26.940001
# Name: close, dtype: float64

# %% [markdown]
# ### Série Temporal

# %%
import matplotlib.pyplot as plt

# tamanho do gráfico
plt.rcParams['figure.figsize'] = (10,5)
# tamanho da legenda eixo x
plt.rcParams['xtick.labelsize'] = 10
# tamanho da legenda eixo y
plt.rcParams['ytick.labelsize'] = 10
# tamanho da fonte do gráfico
plt.rcParams['font.size'] = 10
# tamanho do título
plt.rcParams['axes.titlesize'] = 10

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import seaborn as sns

# %%
sns.lineplot(data=serie);

# %%
len(serie)
# Out:
# 79

# %%
int(len(serie)/4)
# Out:
# 19

# %%
period=int(len(serie)/4)

# %%
serie_dec = seasonal_decompose(serie, period=period)

# %%
serie_dec.observed[:3]
# Out:
# date
# 2022-10-03    32.180000
# 2022-10-04    31.370001
# 2022-10-05    32.549999
# Name: close, dtype: float64

# %%
serie_dec.trend[:3]
# Out:
# date
# 2022-10-03   NaN
# 2022-10-04   NaN
# 2022-10-05   NaN
# Name: trend, dtype: float64

# %%
serie_dec.seasonal[:3]
# Out:
# date
# 2022-10-03    0.099416
# 2022-10-04    0.776960
# 2022-10-05    0.542398
# Name: seasonal, dtype: float64

# %%
serie_dec.resid[:3]
# Out:
# date
# 2022-10-03   NaN
# 2022-10-04   NaN
# 2022-10-05   NaN
# Name: resid, dtype: float64

# %%
serie_dec.plot();

# %% [markdown]
# ### Modelo

# %%
# !pip install sktime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 70.0 MB/s eta 0:00:00
# ...

# %%
from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.naive import NaiveForecaster
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.theta import ThetaForecaster
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.utils.plotting import plot_series

# %%
serie = pd.DataFrame(serie).set_index(data.index.to_period('D'))['close']

# %%
y_train, y_test = temporal_train_test_split(serie)
fh = ForecastingHorizon(y_test.index, is_relative=False)
forecaster = ThetaForecaster(sp=29)  
forecaster.fit(y_train)
y_pred_theta = forecaster.predict(fh)
mean_absolute_percentage_error(y_test, y_pred_theta)
# Out:
# 0.0710056511594885

# %%
forecaster = NaiveForecaster(strategy='last', sp=20)  
forecaster.fit(y_train)
y_pred_naive = forecaster.predict(fh)
mean_absolute_percentage_error(y_test, y_pred_naive)
# Out:
# 0.054354722067450824

# %%
plot_series(y_train, y_test, y_pred_theta, y_pred_naive, 
        labels=["y_train", "y_test", "y_pred_theta", "y_pred_naive"]);
